# %%
import os

# %%
# !pwd
# Out:
# /content/gdrive/My Drive

# %%
os.chdir(r"/content/gdrive/My Drive/")

# %%
# download from Dropbox
# !wget -O siim-acr.zip "https://www.dropbox.com/s/3l6kzwea4o37hdq/siim-acr.zip?dl=1"
# Out:
# --2019-07-30 20:31:51--  https://www.dropbox.com/s/3l6kzwea4o37hdq/siim-acr.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/3l6kzwea4o37hdq/siim-acr.zip [following]
# --2019-07-30 20:31:51--  https://www.dropbox.com/s/dl/3l6kzwea4o37hdq/siim-acr.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2513607630f41a772fbbbc6816.dl.dropboxusercontent.com/cd/0/get/AlsBbYtGSri3qnD51Am_qdIBThjpvYmbSpovLPNiDShoc1Ecz-fNsZWWmLhKrHqUN8ck_7HsuSuQEmt6xvalIclTYog5-16_GLWESzFRoNxJJw/file?dl=1# [following]
# ...

# %%
# !unzip siim-acr.zip
# Out:
# Output hidden; open in https://colab.research.google.com to view.
